# %%
import random
player = 'p'
computer = 'c'

# %%
def first_round():
    player == 'even'
    computer == 'odd'
    global player_run
    player_run = 0
    while True:
        a= int(input("Enter player run: "))
        b= random.randint(1,6)
        print(f'player :{a},compter{b}')
        
        if a==b:
            print("It is a wicket")
            break
        else:
            player_run+=a
            print(f"player run is {player_run}")
        print('------------')

# %%
def second_round():
    player == 'odd'
    computer == 'even'
    global computer_run
    computer_run = 0
    while True:
        a= int(input("Enter player run: "))
        b= random.randint(1,6)
        print(f'player :{a},compter{b}')
        if a==b:
            print("It is a wicket")
            break
        else:
            computer_run+=a
            print(f"computer run is {computer_run}")
        print('------------')

# %%
def win():
    if player_run==computer_run:
        print("tie")
    elif player_run>computer_run:
        print("player wins")
    else:
        print("computer wins")

# %%
first_round()
second_round()
win()
# Out:
# Enter player run: 2
# player :2,compter1
# player run is 2
# ------------
# Enter player run: 4
# player :4,compter1
# player run is 6
# ------------
# Enter player run: 1
# player :1,compter6
# player run is 7
# ------------
# Enter player run: 4
# player :4,compter3
# player run is 11
# ------------
# Enter player run: 5
# player :5,compter4
# player run is 16
# ------------
# Enter player run: 3
# player :3,compter5
# player run is 19
# ------------
# Enter player run: 4
# player :4,compter4
# It is a wicket
# Enter player run: 2
# player :2,compter6
# computer run is 2
# ------------
# Enter player run: 3
# player :3,compter4
# computer run is 5
# ------------
# Enter player run: 4
# player :4,compter6
# computer run is 9
# ------------
# Enter player run: 3
# player :3,compter2
# computer run is 12
# ------------
# Enter player run: 1
# player :1,compter4
# computer run is 13
# ------------
# Enter player run: 3
# player :3,compter5
# computer run is 16
# ------------
# ...
